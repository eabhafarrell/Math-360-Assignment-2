# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import random
from scipy.stats import norm
import scipy.stats as stats
import pandas as pd
weather_df = pd.read_csv("weatherstats_vancouver_daily_2025 (1).csv")
weather_df
# Out:
#        Year  Month  Day  temperature  humidity  precipitation
# 0      2024     12   31         4.95      91.0            1.4
# 1      2024     12   30         4.25      99.0           10.7
# 2      2024     12   29         5.09      96.5            8.1
# 3      2024     12   28         8.55      87.5            7.1
# 4      2024     12   27         6.75      90.5            5.0
# ...     ...    ...  ...          ...       ...            ...
# 10222  1997      1    5         2.60      85.0            0.0
# 10223  1997      1    4         3.85      89.0            1.0
# 10224  1997      1    3         3.85      82.0            0.0
# 10225  1997      1    2         7.45      84.5           15.4
# 10226  1997      1    1         7.35      85.5           11.4
#
# [10227 rows x 6 columns]

# %% [markdown]
# Random variables:
# - Tempreture
# - Humidity
# - Preciptation

# %%
weather_data_january = weather_df[weather_df["Month"] == 1]
weather_data_february = weather_df[weather_df["Month"] == 2]
weather_data_march = weather_df[weather_df["Month"] == 3]
weather_data_april = weather_df[weather_df["Month"] == 4]
weather_data_may = weather_df[weather_df["Month"] == 5]
weather_data_june = weather_df[weather_df["Month"] == 6]
weather_data_july = weather_df[weather_df["Month"] == 7]
weather_data_august = weather_df[weather_df["Month"] == 8]
weather_data_sep = weather_df[weather_df["Month"] == 9]
weather_data_oct = weather_df[weather_df["Month"] == 10]
weather_data_nov = weather_df[weather_df["Month"] == 11]
weather_data_dec = weather_df[weather_df["Month"] == 12]

# %%
plt.bar(weather_data_january["Year"], weather_data_january["temperature"])
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.title("Temperature in January over Years")
plt.show()

# %% [markdown]
# Good, did not see climate change pattern.

# %%
plt.bar(weather_data_january["Year"], weather_data_january["precipitation"])
plt.xlabel("Year")
plt.ylabel("Precipitation")
plt.title("Precipitation in January over Years")
plt.show()

# %%
plt.bar(weather_data_january["Year"], weather_data_january["humidity"])
plt.xlabel("Year")
plt.ylabel("humidity")
plt.title("humidity in January over Years")
plt.show()

# %% [markdown]
# NO CLIMATE CHANGE.

# %%
weather_data_january["temperature"].hist(bins = 30, density = True)
plt.title("Distribution of January Tempreture")
mu_jan_tem = weather_data_january["temperature"].mean()
print(mu_jan_tem)

sig_jan_tem = weather_data_january["temperature"].std()
# Out:
# 4.352188940092166

# %%
weather_data_july["temperature"].hist(bins = 30, density = True)
plt.title("Distribution of July Tempreture")
mu_july_tem = weather_data_july["temperature"].mean()
sig_july_tem = weather_data_july["temperature"].std()

# %% [markdown]
# left skewed

# %%
weather_data_january["precipitation"].hist(bins = 30, density = True)
mu_jan_precip = weather_data_january["precipitation"].mean()
sig_jan_precip = weather_data_january["precipitation"].std()

# %%
weather_data_july["precipitation"].hist(bins = 30, density = True)
mu_july_precip = weather_data_july["precipitation"].mean()
sig_july_precip = weather_data_july["precipitation"].std()

# %% [markdown]
# exponential

# %%
weather_data_january["humidity"].hist(bins = 40, density = True)
mu_jan_humid = weather_data_january["humidity"].mean()
sig_jan_humid = weather_data_january["humidity"].std()

# %%
weather_data_july["humidity"].hist(bins = 40, density = True)
mu_july_humid = weather_data_july["humidity"].mean()
sig_july_humid = weather_data_july["humidity"].std()

# %%
weather_data_january["precipitation"].hist(bins = 30, density = True)
mu_jan_precip = weather_data_january["precipitation"].mean()
sig_jan_precip = weather_data_january["precipitation"].std()

# %%
mu_feb_precip = weather_data_february["precipitation"].mean()
sig_feb_precip = weather_data_february["precipitation"].std()
mu_march_precip = weather_data_march["precipitation"].mean()
sig_march_precip = weather_data_march["precipitation"].std()
mu_april_precip = weather_data_april["precipitation"].mean()
sig_april_precip = weather_data_april["precipitation"].std()
mu_may_precip = weather_data_may["precipitation"].mean()
sig_may_precip = weather_data_may["precipitation"].std()
mu_june_precip = weather_data_june["precipitation"].mean()
sig_june_precip = weather_data_june["precipitation"].std()
mu_august_precip = weather_data_august["precipitation"].mean()
sig_august_precip = weather_data_august["precipitation"].std()
mu_sep_precip = weather_data_sep["precipitation"].mean()
sig_sep_precip = weather_data_sep["precipitation"].std()
mu_oct_precip = weather_data_oct["precipitation"].mean()
sig_oct_precip = weather_data_oct["precipitation"].std()
mu_nov_precip = weather_data_nov["precipitation"].mean()
sig_nov_precip = weather_data_nov["precipitation"].std()
mu_dec_precip = weather_data_dec["precipitation"].mean()
sig_dec_precip = weather_data_dec["precipitation"].std()

# %%
mu_feb_humid = weather_data_february["humidity"].mean()
sig_feb_humid = weather_data_february["humidity"].std()
mu_march_humid = weather_data_march["humidity"].mean()
sig_march_humid = weather_data_march["humidity"].std()
mu_april_humid = weather_data_april["humidity"].mean()
sig_april_humid = weather_data_april["humidity"].std()
mu_may_humid = weather_data_may["humidity"].mean()
sig_may_humid = weather_data_may["humidity"].std()
mu_june_humid = weather_data_june["humidity"].mean()
sig_june_humid = weather_data_june["humidity"].std()
mu_august_humid = weather_data_august["humidity"].mean()
sig_august_humid = weather_data_august["humidity"].std()
mu_sep_humid = weather_data_sep["humidity"].mean()
sig_sep_humid = weather_data_sep["humidity"].std()
mu_oct_humid = weather_data_oct["humidity"].mean()
sig_oct_humid = weather_data_oct["humidity"].std()
mu_nov_humid = weather_data_nov["humidity"].mean()
sig_nov_humid = weather_data_nov["humidity"].std()
mu_dec_humid = weather_data_dec["humidity"].mean()
sig_dec_humid = weather_data_dec["humidity"].std()

# %%
mu_feb_tem = weather_data_february["temperature"].mean()
sig_feb_tem = weather_data_february["temperature"].std()
mu_march_tem = weather_data_march["temperature"].mean()
sig_march_tem = weather_data_march["temperature"].std()
mu_april_tem = weather_data_april["temperature"].mean()
sig_april_tem = weather_data_april["temperature"].std()
mu_may_tem = weather_data_may["temperature"].mean()
sig_may_tem = weather_data_may["temperature"].std()
mu_june_tem = weather_data_june["temperature"].mean()
sig_june_tem = weather_data_june["temperature"].std()
mu_august_tem = weather_data_august["temperature"].mean()
sig_august_tem = weather_data_august["temperature"].std()
mu_sep_tem = weather_data_sep["temperature"].mean()
sig_sep_tem = weather_data_sep["temperature"].std()
mu_oct_tem = weather_data_oct["temperature"].mean()
sig_oct_tem = weather_data_oct["temperature"].std()
mu_nov_tem = weather_data_nov["temperature"].mean()
sig_nov_tem = weather_data_nov["temperature"].std()
mu_dec_tem = weather_data_dec["temperature"].mean()
sig_dec_tem = weather_data_dec["temperature"].std()

# %%
customer_df = pd.read_csv("customer_data_2025 (1).csv")
customer_df
# Out:
#     Hour  January_Frequency_Customers_Alumni_Centre  \
# 0      7                                         87
# 1      8                                        235
# 2      9                                        372
# 3     10                                        410
# 4     11                                        533
# 5     12                                        710
# 6     13                                        747
# 7     14                                        815
# 8     15                                        737
# 9     16                                        704
# 10    17                                        624
# 11    18                                        107
#
#     January_Frequency_Customers_Sauder  \
# 0                                   68
# 1                                  187
# 2                                  305
# 3                                  301
# 4                                  414
# 5                                  598
# ...

# %%
jan_daily_mean = (customer_df["January_Frequency_Customers_Alumni_Centre"].sum()
                  + customer_df["January_Frequency_Customers_Sauder"].sum()) / 31
print(jan_daily_mean)
july_daily_mean = (customer_df["July_Frequency_Customers_Alumni_Centre"].sum()
                  + customer_df["July_Frequency_Customers_Sauder"].sum()) / 31
print(july_daily_mean)
# Out:
# 350.38709677419354
# 175.41935483870967

# %%
jan_daily_mean_alu = customer_df["January_Frequency_Customers_Alumni_Centre"].sum()/31
jan_daily_mean_sauder = customer_df["January_Frequency_Customers_Sauder"].sum()/31
july_daily_mean_alu = customer_df["July_Frequency_Customers_Alumni_Centre"].sum()/31
july_daily_mean_sauder = customer_df["July_Frequency_Customers_Sauder"].sum()/31

# %%
print(july_daily_mean_alu)
print(july_daily_mean_sauder)
# Out:
# 107.09677419354838
# 68.3225806451613

# %%
 # Apply monte carlo to the beta values
ass = [-3, -1, 0, 1, 3]
bss = [10, 20,30]
css = [-5,-3,-2,-1,0]
N = 2000 
C0 = jan_daily_mean
C = july_daily_mean
T0 = mu_jan_tem
P0 = mu_jan_precip
H0 = mu_jan_humid
for a in ass:
    for b in bss:
        for c in css:
            T = np.random.normal(loc = mu_july_tem, scale = sig_july_tem, size = N)
            P = np.random.exponential(scale = mu_july_precip, size = N)
            H = np.random.normal(loc = mu_july_humid, scale = sig_july_humid, size = N)
            num = C0 + a * (T - T0)**2 - b * (P - P0) - c * (H - H0)**2
            C1 = np.maximum(num, 0)
            print("a = ", a)
            print("b = ", b)
            print("c = ", c)
            print("mean = ", C1.mean())
# Out:
# a =  -3
# b =  10
# c =  -5
# mean =  976.9634320531709
# a =  -3
# b =  10
# c =  -3
# mean =  527.4569764781378
# a =  -3
# b =  10
# c =  -2
# mean =  320.1870729988281
# a =  -3
# b =  10
# c =  -1
# mean =  114.9298685549759
# a =  -3
# b =  10
# c =  0
# mean =  6.085668106424777
# a =  -3
# b =  20
# c =  -5
# mean =  1010.586059039557
# a =  -3
# b =  20
# c =  -3
# mean =  568.7636221528085
# a =  -3
# b =  20
# c =  -2
# mean =  343.0550502289983
# a =  -3
# b =  20
# c =  -1
# mean =  145.6090096454236
# a =  -3
# b =  20
# c =  0
# mean =  12.08793546872151
# a =  -3
# b =  30
# c =  -5
# mean =  1063.3307256789803
# a =  -3
# b =  30
# c =  -3
# mean =  618.274637101053
# a =  -3
# b =  30
# c =  -2
# mean =  379.6846840060393
# a =  -3
# b =  30
# c =  -1
# mean =  171.29831039966297
# a =  -3
# b =  30
# c =  0
# mean =  22.689243972717826
# a =  -1
# b =  10
# c =  -5
# mean =  1395.8670220887607
# a =  -1
# b =  10
# c =  -3
# mean =  896.7168519767108
# a =  -1
# ...

# %%
 # Apply monte carlo to the beta values
N = 2000 
C0 = jan_daily_mean
C = july_daily_mean
T0 = mu_jan_tem
P0 = mu_jan_precip
H0 = mu_jan_humid
a  = -3
b = 32
c = -1
T = np.random.normal(loc = mu_july_tem, scale = sig_july_tem, size = N)
P = np.random.exponential(scale = mu_july_precip, size = N)
H = np.random.normal(loc = mu_july_humid, scale = sig_july_humid, size = N)
num = C0 + a * (T - T0)**2 - b * (P - P0) - c * (H - H0)**2
C1 = np.maximum(num, 0)
print("a = ", a)
print("b = ", b)
print("c = ", c)
print("mean = ", C1.mean())
            

kde_Y = stats.gaussian_kde(C1)

plt.hist(C1,bins=50,density=True)

t = np.linspace(0,1700,3000)
plt.plot(t,kde_Y(t))

plt.show()
# Out:
# a =  -3
# b =  32
# c =  -1
# mean =  175.5343241205202

# %%
#alumni NOT SURE IF WE SHOULD KEEP THIS, SEEMS REDUNDANT
N = 2000 
C0 = jan_daily_mean_alu
T0 = mu_jan_tem
P0 = mu_jan_precip
H0 = mu_jan_humid
a  = -3
b = 32
c = -1
T = np.random.normal(loc = mu_july_tem, scale = sig_july_tem, size = N)
P = np.random.exponential(scale = mu_july_precip, size = N)
H = np.random.normal(loc = mu_july_humid, scale = sig_july_humid, size = N)
num = C0 + a * (T - T0)**2 - b * (P - P0) - c * (H - H0)**2
C1 = np.maximum(num, 0)
print("a = ", a)
print("b = ", b)
print("c = ", c)
print("mean = ", C1.mean())
            

kde_Y = stats.gaussian_kde(C1)

plt.hist(C1,bins=50,density=True)

t = np.linspace(0,1700,3000)
plt.plot(t,kde_Y(t))

plt.show()
# Out:
# a =  -3
# b =  32
# c =  -1
# mean =  85.27158135415456

# %%
# SAME HERE
N = 2000 
C0 = jan_daily_mean_sauder
T0 = mu_jan_tem
P0 = mu_jan_precip
H0 = mu_jan_humid
a  = -3
b = 32
c = -1
T = np.random.normal(loc = mu_july_tem, scale = sig_july_tem, size = N)
P = np.random.exponential(scale = mu_july_precip, size = N)
H = np.random.normal(loc = mu_july_humid, scale = sig_july_humid, size = N)
num = C0 + a * (T - T0)**2 - b * (P - P0) - c * (H - H0)**2
C1 = np.maximum(num, 0)
print("a = ", a)
print("b = ", b)
print("c = ", c)
print("mean = ", C1.mean())
            

kde_Y = stats.gaussian_kde(C1)

plt.hist(C1,bins=50,density=True)

t = np.linspace(0,1700,3000)
plt.plot(t,kde_Y(t))

plt.show()
# Out:
# a =  -3
# b =  32
# c =  -1
# mean =  70.23206930456963

# %% [markdown]
# we then use what we have for a, b, c for other months.

# %%
#we define a function so that we don't have to repeat the thing again and again
def monte_carlo_monthly_mean(mu_tem, sd_tem, mu_precip, mu_humid, sd_humid,
                   C0, T0 = mu_jan_tem, P0 = mu_jan_precip, H0 = mu_jan_humid, a = -3, b = 32, c = -1,
                   N=2000):
    T = np.random.normal(loc=mu_tem, scale=sd_tem, size=N)
    P = np.random.exponential(scale=mu_precip, size=N)   # if you're using exponential
    H = np.random.normal(loc=mu_humid, scale=sd_humid, size=N)
    num = C0 + a * (T - T0)**2 - b * (P - P0) - c * (H - H0)**2
    C1 = np.maximum(num, 0)

    return C1.mean()

# %%
months = ["January", "February", "March", "April", "May", "June",
          "July", "August", "September", "October", "November", "December"]
month = np.arange(0,12,1)
mu_tem = [mu_jan_tem, mu_feb_tem, mu_march_tem, mu_april_tem,
        mu_may_tem, mu_june_tem, mu_july_tem, mu_august_tem,
        mu_sep_tem, mu_oct_tem, mu_nov_tem, mu_dec_tem]
sd_tem = [sig_jan_tem, sig_feb_tem, sig_march_tem, sig_april_tem,
        sig_may_tem, sig_june_tem, sig_july_tem, sig_august_tem,
        sig_sep_tem, sig_oct_tem, sig_nov_tem, sig_dec_tem]
mu_precip = [mu_jan_precip, mu_feb_precip, mu_march_precip, mu_april_precip,
        mu_may_precip, mu_june_precip, mu_july_precip, mu_august_precip,
        mu_sep_precip, mu_oct_precip, mu_nov_precip, mu_dec_precip]
sd_precip = [sig_jan_precip, sig_feb_precip, sig_march_precip, sig_april_precip,
        sig_may_precip, sig_june_precip, sig_july_precip, sig_august_precip,
        sig_sep_precip, sig_oct_precip, sig_nov_precip, sig_dec_precip]
mu_humid = [mu_jan_humid, mu_feb_humid, mu_march_humid, mu_april_humid,
        mu_may_humid, mu_june_humid, mu_july_humid, mu_august_humid,
        mu_sep_humid, mu_oct_humid, mu_nov_humid, mu_dec_humid]
sd_humid = [sig_jan_humid, sig_feb_humid, sig_march_humid, sig_april_humid,
        sig_may_humid, sig_june_humid, sig_july_humid, sig_august_humid,
        sig_sep_humid, sig_oct_humid, sig_nov_humid, sig_dec_humid]

# %%
#alumni one
monthly_mean_alu = []
for i in month:
    monthly_avg = monte_carlo_monthly_mean(mu_tem = mu_tem[i], sd_tem = sd_tem[i],
                               mu_precip = mu_precip[i],
                               mu_humid = mu_humid[i],sd_humid = sd_humid[i],
                               C0 = jan_daily_mean_alu)
    monthly_mean_alu.append(monthly_avg)
results_alu = pd.DataFrame({
    "Month": months,
    "Mean_customers": monthly_mean_alu
})
total_mean_customers_alu = results_alu["Mean_customers"].sum()

# %%
#sauder
monthly_mean_sauder = []
for i in month:
    monthly_avg = monte_carlo_monthly_mean(mu_tem = mu_tem[i], sd_tem = sd_tem[i],
                               mu_precip = mu_precip[i],
                               mu_humid = mu_humid[i],sd_humid = sd_humid[i],
                               C0 = jan_daily_mean_sauder)
    monthly_mean_sauder.append(monthly_avg)


results_sauder = pd.DataFrame({
    "Month": months,
    "Mean_customers": monthly_mean_sauder
})

total_mean_customers_sauder = results_sauder["Mean_customers"].sum()
print(total_mean_customers_sauder)
# Out:
# 2458.845109679437

# %%
results_sauder
# Out:
#         Month  Mean_customers
# 0     January      225.969417
# 1    February      358.177030
# 2       March      324.699461
# 3       April      366.172568
# 4         May      243.688161
# 5        June      150.322878
# 6        July       74.197998
# 7      August       39.644894
# 8   September       76.525668
# 9     October      163.722511
# 10   November      202.295819
# 11   December      233.428705

# %%
total_mean_customers_alu = results_alu["Mean_customers"].sum()
print(total_mean_customers_alu)
# Out:
# 2828.6953131350224

# %%
results_alu
# Out:
#         Month  Mean_customers
# 0     January      250.651945
# 1    February      390.297414
# 2       March      361.609655
# 3       April      411.421245
# 4         May      280.704752
# 5        June      196.785492
# 6        July       83.261785
# 7      August       56.179454
# 8   September       93.259278
# 9     October      196.796560
# 10   November      240.760761
# 11   December      266.966972
